# %%
import praw
import pandas as pd

# %%
CLIENT_ID = "iL1WH1iZl3Q9eg"
CLIENT_SECRET = "av33tHFK7E059VrVLWYGgzv_OB0"
USER_AGENT = f"python:{CLIENT_ID}:0.1 (by /u/mainmancudi)"

# %%
USER_AGENT
# Out:
# 'python:iL1WH1iZl3Q9eg:0.1 (by /u/mainmancudi)'

# %%
api = praw.Reddit(
    client_id = CLIENT_ID,
    client_secret = CLIENT_SECRET,
    user_agent = USER_AGENT
)

# %%
api.read_only
list = [{
    "title" : "something else",
    "example" : "jaja"
}]
list_empty = []

# %%
for submission in api.subreddit('leagueoflegends').hot(limit=100):
    item = {
     "title" : submission.title,
     "score" : submission.score,
     "num_comments" : submission.num_comments
    }
    list_empty.append(item)

# %%
print(list_empty)
# Out:
# [{'title': '2018 World Championship / Group Stage - Day 8 / Live Discussion', 'score': 18, 'num_comments': 92}, {'title': 'Spoiler Rule Update', 'score': 365, 'num_comments': 1}, {'title': '100 Thieves just shut down YouTube in a desperate bid to prevent Group D from happening', 'score': 1904, 'num_comments': 144}, {'title': 'Chinese Reaction to Doublelift After Worlds', 'score': 2854, 'num_comments': 775}, {'title': 'While C9 has made it out of groups 4 times now, all other NA teams combined made it out of groups only ONCE in 7 years.', 'score': 8004, 'num_comments': 1512}, {'title': "Doublelift talks to Travis: 'There's no one as disappointed, as frustrated, as critical as us or as me. I've been trying to make it out of groups for eight years. You should criticize your favorite teams or players and tell them they played like sh*t, but no one knows it more than the player.'", 'score': 4237, 'num_comments': 1344}, {'title': 'G2 Grabbz: "Honestly, in this Worlds I think nobody is unbeatable. There’s no SKT level team where you’re like "oh shit we want to avoid them""', 'score': 1268, 'num_comments': 239}, {'title': 'I know appreciation threads suck but Sjokz really deserves some love.', 'score': 3623, 'num_comments': 366}, {'title': 'TL Doublelift Emotional Interview Q_Q', 'score': 5265, 'num_comments': 2244}, {'title': "K/DA Kai'Sa fanart by @raikoart", 'score': 1087, 'num_comments': 72}, {'title': 'The train is bound for CHAMPION station [CN fanart]', 'score': 285, 'num_comments': 31}, {'title': 'K/DA Crowd on the PBE upon entering Summoner Rift', 'score': 374, 'num_comments': 37}, {'title': 'AFs Kuro: "We\'ve actually had a lot of scrims against C9, and I feel that their pick/bans are on point."', 'score': 171, 'num_comments': 25}, {'title': 'KT Smeb on C9 Licorice: "I think he’s a really good player. Since he has a lot of pocket picks, I have to be ready with a lot of counters to those picks."', 'score': 832, 'num_comments': 150}, {'title': 'TSM Zven on playing other games while being at an international event', 'score': 716, 'num_comments': 614}, {'title': 'Mowgli: "Vitality\'s performance was amazing. I\'m really sad that they didn\'t make it out."', 'score': 1176, 'num_comments': 177}, {'title': "Chinese casters' comments on TL Pobelter, Olleh and Doublelift (eng sub)", 'score': 562, 'num_comments': 313}, {'title': 'EDward Gaming vs. KT Rolster / 2018 World Championship - Group C / Post-Match Discussion', 'score': 2957, 'num_comments': 1929}, {'title': 'MAD Team is the first major region team to finish group 0-6.', 'score': 1879, 'num_comments': 553}, {'title': 'Yassuo (Moe) and Akali (TF Blade) Fan Art', 'score': 1291, 'num_comments': 264}, {'title': 'EDward Gaming vs. Team Liquid / 2018 World Championship - Group C / Post-Match Discussion', 'score': 2175, 'num_comments': 1612}, {'title': 'Just like 2017, all three play-in teams from NA, EU and CN have made quarters.', 'score': 2296, 'num_comments': 545}, {'title': "You shouldn't have shutdown gold after only 2 kills", 'score': 4029, 'num_comments': 342}, {'title': 'With Gen.G out of Worlds we still have a chance of seeing a team get their second Championship.', 'score': 317, 'num_comments': 91}, {'title': "Going forward, I think LCS splits should be accompanied by their own missions and promotional content just like this year's Worlds is.", 'score': 782, 'num_comments': 37}, {'title': 'It would be hilarious if 100T somehow upset IG', 'score': 246, 'num_comments': 113}, {'title': 'Fun fact: from 2014-2017, 1st seeds have actually had a lower win% in groups than 2nd or 3rd seeds. In addition, 2015 SKT is the only #1 seed since S4 to ever make a Worlds Final.', 'score': 78, 'num_comments': 14}, {'title': 'Uzi in interview after tiebreaker: "We left Zilean up on purpose"', 'score': 613, 'num_comments': 272}, {'title': 'G2 Hjarnan: "My Heimer will beat Uzi, that’s for sure. But ADC vs ADC, I need to get a really good matchup“', 'score': 1931, 'num_comments': 314}, {'title': ...

# %%
df = pd.DataFrame(list_empty)

# %%
df
# Out:
#     num_comments  score                                              title
# 0             92     18  2018 World Championship / Group Stage - Day 8 ...
# 1              1    365                                Spoiler Rule Update
# 2            144   1904  100 Thieves just shut down YouTube in a desper...
# 3            775   2854        Chinese Reaction to Doublelift After Worlds
# 4           1512   8004  While C9 has made it out of groups 4 times now...
# 5           1344   4237  Doublelift talks to Travis: 'There's no one as...
# 6            239   1268  G2 Grabbz: "Honestly, in this Worlds I think n...
# 7            366   3623  I know appreciation threads suck but Sjokz rea...
# 8           2244   5265              TL Doublelift Emotional Interview Q_Q
# 9             72   1087                    K/DA Kai'Sa fanart by @raikoart
# 10            31    285  The train is bound for CHAMPION station [CN fa...
# 11            37    374  K/DA Crowd on the PBE upon entering Summoner Rift
# 12            25    171  AFs Kuro: "We've actually had a lot of scrims ...
# 13           150    832  KT Smeb on C9 Licorice: "I think he’s a really...
# 14           614    716  TSM Zven on playing other games while being at...
# 15           177   1176  Mowgli: "Vitality's performance was amazing. I...
# 16           313    562  Chinese casters' comments on TL Pobelter, Olle...
# 17          1929   2957  EDward Gaming vs. KT Rolster / 2018 World Cham...
# 18           553   1879  MAD Team is the first major region team to fin...
# 19           264   1291          Yassuo (Moe) and Akali (TF Blade) Fan Art
# 20          1612   2175  EDward Gaming vs. Team Liquid / 2018 World Cha...
# 21           545   2296  Just like 2017, all three play-in teams from N...
# 22           342   4029  You shouldn't have shutdown gold after only 2 ...
# 23            91    317  With Gen.G out of Worlds we still have a chanc...
# 24            37    782  Going forward, I think LCS splits should be ac...
# 25           113    246     It would be hilarious if 100T somehow upset IG
# 26            14     78  Fun fact: from 2014-2017, 1st seeds have actua...
# 27           272    613  Uzi in interview after tiebreaker: "We left Zi...
# 28           314   1931  G2 Hjarnan: "My Heimer will beat Uzi, that’s f...
# 29           119    247  "Liquid [...] held 60% of the LCS players" - i...
# ..           ...    ...                                                ...
# 70             6      6  A lot of people have joined this subreddit in ...
# 71           111    108  It feels unfair to choose between honoring the...
# 72            19     76  EDG Coach NoFe: "The team kind of feels like a...
# 73            42     96                    My first official high elo game
# 74            54    103    Spoiler. Why you should root for EDG against TL
# 75             1      3  Reminder: You can watch Words from FNC virtual...
# 76            14     43         THEORY - The Seven Deadly Sins (LONG POST)
# 77             8      3                   Does Lux have a wand or a staff?
# 78           111     26                      Why do you play who you play?
# 79             8     19                                          3D Models
# 80             3     48             Prestige KDA Kai'sa Sketch Fanart [OC]
# 81             9     80  Star Guardian Chibi Urgot , Chibi Victorious O...
# 82           582   2516             Team Liquid & Fnatic motivation thread
# 83           482   1721  Regardless of how C9 performs going forwards, ...
# 84            12     47  Cloud9’s Ascension from 10th to Worlds Quarter...
# 85          2857   6595  Flash Wolves vs. G2 Esports / 2018 World Champ...
# 86            12     30  KT Smeb, Mata, Deft Interviews and Korean Reac...
# 87             4      3         Items with percentual Health or Mana cost?
# 88             1     23  [Spoiler] Interesting parallel between c9 2017...
# 89            26     32                    G2 Perkz | Rise from the Shroud
# 90             1      3         Super pumped about my two worlds crossing.
# 91             4      3                                  The Perfect Throw
# 92            37     20  What EU LCS 2019 'Super team' would you like t...
# 93          4084    161  2018 World Championship / Group Stage - Day 7 ...
# 94            89     43                        How are your pick'em going?
# 95            33      4                    How to play support for dummies
# 96             2     10                                    Alistar outplay
# 97             6      2                     Does Stormrazor stack with IE?
# 98           265    211            Cycle of Hatred between EU and NA fans.
# 99             0      2      2018 World Championship Group D Tease (Day 8)
#
# [100 rows x 3 columns]

# %%
df.to_json("test.JSON")
